# %% [markdown]
# # Indexing

# %%
import pandas as pd

# %%
oo = pd.read_csv('data/olympics.csv',skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ## Indexing

# %%
type(oo.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
oo.index[100]
# Out:
# 100

# %% [markdown]
# ### index 是不可修改的

# %%
oo.index[100] = 101
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c8d45368e4cf> in <module>
# ----> 1 oo.index[100] = 101
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    2063
#    2064     def __setitem__(self, key, value):
# -> 2065         raise TypeError("Index does not support mutable operations")
#    2066
#    2067     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# ## 数据索引的设置方式 set_index()

# %%
oo.set_index('Athlete')
# Out:
#                                 City  Edition      Sport       Discipline  \
# Athlete
# HAJOS, Alfred                 Athens     1896   Aquatics         Swimming
# HERSCHMANN, Otto              Athens     1896   Aquatics         Swimming
# DRIVAS, Dimitrios             Athens     1896   Aquatics         Swimming
# MALOKINIS, Ioannis            Athens     1896   Aquatics         Swimming
# CHASAPIS, Spiridon            Athens     1896   Aquatics         Swimming
# CHOROPHAS, Efstathios         Athens     1896   Aquatics         Swimming
# HAJOS, Alfred                 Athens     1896   Aquatics         Swimming
# ANDREOU, Joannis              Athens     1896   Aquatics         Swimming
# CHOROPHAS, Efstathios         Athens     1896   Aquatics         Swimming
# NEUMANN, Paul                 Athens     1896   Aquatics         Swimming
# PEPANOS, Antonios             Athens     1896   Aquatics         Swimming
# ...

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ath = oo.set_index('Athlete');

# %%
ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo.set_index('Athlete',inplace=True)

# %%
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %% [markdown]
# ## reset_index() 索引复位

# %%
ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath1 = ath.reset_index()
ath1.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.reset_index(inplace=True)
oo.head()
# Out:
#    index             Athlete    City  Edition     Sport Discipline  NOC  \
# 0      0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN
# 1      1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT
# 2      2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE
# 3      3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE
# 4      4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE
#
#   Gender                       Event Event_gender   Medal
# 0    Men              100m freestyle            M    Gold
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver

# %% [markdown]
# ## sort_index()

# %%
ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.sort_index(inplace=True,ascending=False)
ath.head()
# Out:
#                        City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTRAND, Per-Olof  Helsinki     1952  Aquatics   Swimming  SWE    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
#
#                                            Event Event_gender   Medal
# Athlete
# ÖSTRAND, Per-Olof                 400m freestyle            M  Bronze
# ÖSTMO, Ole                      free rifle, team            M  Silver
# ÖSTMO, Ole            army rifle, 300m, standing            M  Silver
# ÖSTMO, Ole               army rifle, 300m, prone            M  Bronze
# ÖSTMO, Ole         army rifle, 300m, 3 positions            M  Bronze

# %% [markdown]
# ## loc[..]

# %%
oo.loc[1]
# Out:
# index                          1
# Athlete         HERSCHMANN, Otto
# City                      Athens
# Edition                     1896
# Sport                   Aquatics
# Discipline              Swimming
# NOC                          AUT
# Gender                       Men
# Event             100m freestyle
# Event_gender                   M
# Medal                     Silver
# Name: 1, dtype: object

# %%
oo.loc[[1,3,5,7]]
# Out:
#    index                Athlete    City  Edition     Sport Discipline  NOC  \
# 1      1       HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT
# 3      3     MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE
# 5      5  CHOROPHAS, Efstathios  Athens     1896  Aquatics   Swimming  GRE
# 7      7       ANDREOU, Joannis  Athens     1896  Aquatics   Swimming  GRE
#
#   Gender                       Event Event_gender   Medal
# 1    Men              100m freestyle            M  Silver
# 3    Men  100m freestyle for sailors            M    Gold
# 5    Men             1200m freestyle            M  Bronze
# 7    Men             1200m freestyle            M  Silver

# %%
ath.head()
# Out:
#                        City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTRAND, Per-Olof  Helsinki     1952  Aquatics   Swimming  SWE    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
#
#                                            Event Event_gender   Medal
# Athlete
# ÖSTRAND, Per-Olof                 400m freestyle            M  Bronze
# ÖSTMO, Ole                      free rifle, team            M  Silver
# ÖSTMO, Ole            army rifle, 300m, standing            M  Silver
# ÖSTMO, Ole               army rifle, 300m, prone            M  Bronze
# ÖSTMO, Ole         army rifle, 300m, 3 positions            M  Bronze

# %%
oo[oo.Athlete == 'ÖSTMO, Ole']
# Out:
#      index     Athlete   City  Edition     Sport Discipline  NOC Gender  \
# 596    596  ÖSTMO, Ole  Paris     1900  Shooting   Shooting  NOR    Men
# 603    603  ÖSTMO, Ole  Paris     1900  Shooting   Shooting  NOR    Men
# 608    608  ÖSTMO, Ole  Paris     1900  Shooting   Shooting  NOR    Men
# 621    621  ÖSTMO, Ole  Paris     1900  Shooting   Shooting  NOR    Men
#
#                              Event Event_gender   Medal
# 596  army rifle, 300m, 3 positions            M  Bronze
# 603        army rifle, 300m, prone            M  Bronze
# 608     army rifle, 300m, standing            M  Silver
# 621               free rifle, team            M  Silver

# %%
ath.loc['ÖSTMO, Ole']
# Out:
#              City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTMO, Ole  Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole  Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole  Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole  Paris     1900  Shooting   Shooting  NOR    Men
#
#                                     Event Event_gender   Medal
# Athlete
# ÖSTMO, Ole               free rifle, team            M  Silver
# ÖSTMO, Ole     army rifle, 300m, standing            M  Silver
# ÖSTMO, Ole        army rifle, 300m, prone            M  Bronze
# ÖSTMO, Ole  army rifle, 300m, 3 positions            M  Bronze

# %% [markdown]
# ## iloc

# %% [markdown]
# ## iloc 是假设是以1，2，3这种作为数据索引的

# %%
ath.sort_index(ascending=True,inplace=True)
ath.head()
# Out:
#                               City  Edition       Sport   Discipline  NOC  \
# Athlete
# AABYE, Edgar                 Paris     1900  Tug of War   Tug of War  ZZX
# AALTONEN, Arvo Ossian      Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Arvo Ossian      Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Paavo Johannes    London     1948  Gymnastics  Artistic G.  FIN
# AALTONEN, Paavo Johannes  Helsinki     1952  Gymnastics  Artistic G.  FIN
#
#                          Gender              Event Event_gender   Medal
# Athlete
# AABYE, Edgar                Men         tug of war            M    Gold
# AALTONEN, Arvo Ossian       Men  400m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian       Men  200m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes    Men              vault            M    Gold
# AALTONEN, Paavo Johannes    Men   team competition            M  Bronze

# %%
ath.iloc[1]
# Out:
# City                      Antwerp
# Edition                      1920
# Sport                    Aquatics
# Discipline               Swimming
# NOC                           FIN
# Gender                        Men
# Event           400m breaststroke
# Event_gender                    M
# Medal                      Bronze
# Name: AALTONEN, Arvo Ossian, dtype: object

# %%
ath.iloc[[1,3,5,7]]
# Out:
#                              City  Edition       Sport   Discipline  NOC  \
# Athlete
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
#
#                          Gender                 Event Event_gender   Medal
# Athlete
# AALTONEN, Arvo Ossian       Men     400m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes    Men                 vault            M    Gold
# AALTONEN, Paavo Johannes    Men      team competition            M    Gold
# AALTONEN, Paavo Johannes    Men  individual all-round            M  Bronze

# %%
ath.iloc[50:55]
# Out:
#                             City  Edition      Sport       Discipline  NOC  \
# Athlete
# ABDUL, Rashid III         Mexico     1968     Hockey           Hockey  PAK
# ABDUL, Rashid IV     Los Angeles     1984     Hockey           Hockey  PAK
# ABDUL, Waheed               Rome     1960     Hockey           Hockey  PAK
# ABDULBEKOV, Zagalav       Munich     1972  Wrestling  Wrestling Free.  URS
# ABDULLAYEV, Namig         Sydney     2000  Wrestling  Wrestling Free.  AZE
#
#                     Gender                      Event Event_gender Medal
# Athlete
# ABDUL, Rashid III      Men                     hockey            M  Gold
# ABDUL, Rashid IV       Men                     hockey            M  Gold
# ABDUL, Waheed          Men                     hockey            M  Gold
# ABDULBEKOV, Zagalav    Men  57 - 62kg (featherweight)            M  Gold
# ABDULLAYEV, Namig      Men                  48 - 54kg            M  Gold

# %% [markdown]
# ## challenge

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
oo = pd.read_csv('data/olympics.csv',skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
noc = pd.read_csv('data/code_data/data/Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')
noc.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %% [markdown]
# ## Plot the total number of medals awarded at each of the Olympic games throughout history.

# %%
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Edition.value_counts().plot();

# %%
type(oo.Edition.value_counts())
# Out:
# pandas.core.series.Series

# %%
oo.Edition.value_counts().sort_index().plot()

# %% [markdown]
# ## Which countries did not win a medal in the 2008 Olympics? How many countries were there?

# %%
bj = oo[(oo.Edition == 2008)]
bj.head()
# Out:
#           City  Edition     Sport Discipline           Athlete  NOC Gender  \
# 27174  Beijing     2008  Aquatics     Diving    GALPERIN, Gleb  RUS    Men
# 27175  Beijing     2008  Aquatics     Diving  MITCHAM, Matthew  AUS    Men
# 27176  Beijing     2008  Aquatics     Diving       ZHOU, Luxin  CHN    Men
# 27177  Beijing     2008  Aquatics     Diving         WANG, Xin  CHN  Women
# 27178  Beijing     2008  Aquatics     Diving      CHEN, Ruolin  CHN  Women
#
#               Event Event_gender   Medal
# 27174  10m platform            M  Bronze
# 27175  10m platform            M    Gold
# 27176  10m platform            M  Silver
# 27177  10m platform            W  Bronze
# 27178  10m platform            W    Gold

# %%
noc.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
noc[noc['Country'] != noc['Country.1']]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
del noc['Country.1']

# %%
noc.head()
# Out:
#            Country Int Olympic Committee code ISO code
# 0      Afghanistan                        AFG       AF
# 1          Albania                        ALB       AL
# 2          Algeria                        ALG       DZ
# 3  American Samoa*                        ASA       AS
# 4          Andorra                        AND       AD

# %%
noc.set_index('Int Olympic Committee code', inplace=True)
noc.head()
# Out:
#                                     Country ISO code
# Int Olympic Committee code
# AFG                             Afghanistan       AF
# ALB                                 Albania       AL
# ALG                                 Algeria       DZ
# ASA                         American Samoa*       AS
# AND                                 Andorra       AD

# %%
medal_2008 = bj.NOC.value_counts()
medal_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
# KOR     78
# GBR     77
# FRA     76
# BRA     75
# ESP     71
# NED     62
# ARG     51
# JPN     51
# CUB     47
# ITA     42
# CAN     34
# UKR     31
# BLR     30
# HUN     27
# NGR     24
# ROU     22
# NOR     22
# POL     20
# DEN     18
# JAM     17
# SRB     15
# NZL     14
# ISL     14
# KEN     14
# KAZ     13
#       ...
# IRL      3
# SIN      3
# IND      3
# AUT      3
# EST      3
# LAT      3
# TJK      2
# POR      2
# IRI      2
# DOM      2
# MAR      2
# COL      2
# ALG      2
# KGZ      2
# TOG      1
# TUN      1
# PAN      1
# RSA      1
# CHI      1
# AFG      1
# CMR      1
# SUD      1
# EGY      1
# MDA      1
# VEN      1
# MRI      1
# MAS      1
# ISR      1
# ECU      1
# VIE      1
# Name: NOC, Length: 86, dtype: int64

# %%
noc['medal_2008'] = medal_2008
noc.head()
# Out:
#                                     Country ISO code  medal_2008
# Int Olympic Committee code
# AFG                             Afghanistan       AF         1.0
# ALB                                 Albania       AL         NaN
# ALG                                 Algeria       DZ         2.0
# ASA                         American Samoa*       AS         NaN
# AND                                 Andorra       AD         NaN

# %%
no_medal = noc[noc.medal_2008.isnull()]
no_medal.head()
# Out:
#                                         Country ISO code  medal_2008
# Int Olympic Committee code
# ALB                                     Albania       AL         NaN
# ASA                             American Samoa*       AS         NaN
# AND                                     Andorra       AD         NaN
# ANG                                      Angola       AO         NaN
# ANT                         Antigua and Barbuda       AG         NaN

# %%
len(no_medal.index)
# Out:
# 117
